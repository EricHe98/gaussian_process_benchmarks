# %%
import os
import torch
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.set_default_dtype(torch.float64)

import botorch
from botorch.acquisition import ExpectedImprovement, NoisyExpectedImprovement,\
    PosteriorMean, UpperConfidenceBound
from botorch.optim import optimize_acqf
from botorch.fit import fit_gpytorch_mll
from botorch.acquisition.monte_carlo import qExpectedImprovement, qProbabilityOfImprovement, qUpperConfidenceBound
from botorch.sampling.normal import SobolQMCNormalSampler
from botorch.exceptions import BadInitialCandidatesWarning

import time
import warnings
from botorch.acquisition.objective import ConstrainedMCObjective
from botorch.test_functions import Hartmann, Ackley, EggHolder, Cosine8, DixonPrice, Griewank, Levy, Powell

from botorch.models import SingleTaskGP, FixedNoiseGP, ModelListGP
from gpytorch.mlls.sum_marginal_log_likelihood import SumMarginalLogLikelihood
from gpytorch.mlls import ExactMarginalLogLikelihood
from gpytorch.kernels import MaternKernel

from scipy.stats.qmc import Sobol
import pandas as pd

# pose as a maximization problem for all
test_functions = {
    'sinc_plus_2':{
        'function':lambda x: torch.sinc(x + 2.),
        'bounds':torch.tensor([-20., 20.]).unsqueeze(-1)
    },
    'hartmann':{
        'function':Hartmann(negate=True),
        'bounds':torch.tensor([[0] * 6, [1] * 6]),
        'maximum_value':torch.tensor(-3.32237),
        'maximum_point':torch.tensor([[0.20169, 0.150011, 0.476874, 0.275332, 0.311652, 0.6573]])
    },
    'ackley':{
        'function':Ackley(negate=True),
        'bounds':torch.tensor([[-29.768] * 2, [32.768] * 2]),
        'maximum_value':torch.tensor(0),
        'maximum_point':torch.tensor([[0,0]])
    },
    'eggholder':{
        'function':EggHolder(negate=True),
        'bounds':torch.tensor([[-512] * 2, [512] * 2]),
        'maximum_value':torch.tensor(959.6407),
        'maximum_point':torch.tensor([[512, 404.2319]])
    },
    'cosine':{
        'function':Cosine8(negate=False),
        'bounds':torch.tensor([[-1] * 8, [0.7] * 8]),
        'maximum_value':torch.tensor(0.8),
        'maximum_point':torch.tensor([[0,0,0,0,0,0,0,0]])
    },
    'dixonprice':{
        'function':DixonPrice(dim=8, negate=True),
        'bounds':torch.tensor([[-10] * 8, [10] * 8]),
        'maximum_value':torch.tensor(0),
#         'maximum_point':torch.tensor([[1, ]]) # too complicated
    },
    'griewank':{
        'function':Griewank(dim=8, negate=True),
        'bounds':torch.tensor([[-600] * 8,[500] * 8]),
        'maximum_value':torch.tensor(0),
        'maximum_point':torch.tensor([[0,0,0,0,0,0,0,0]])
    },
    'levy':{
        'function':Levy(dim=8),
        'bounds':torch.tensor([[-10] * 8, [10] * 8]),
        'maximum_value':torch.tensor(0),
        'maximum_point':torch.tensor([[1,1,1,1,1,1,1,1]])
    },
    'powell':{
        'function':Powell(dim=4, negate=True),
        'bounds':torch.tensor([[-4] * 8, [5] * 8]),
        'maximum_value':torch.tensor(0),
        'maximum_point':torch.tensor([[0,0,0,0,0,0,0,0]])
    }
}
for k in test_functions.keys():
    test_functions[k]['bounds'] = test_functions[k]['bounds'].double()
    
models = {
    'matern2_5':{
        'gp':SingleTaskGP,
        'likelihood':ExactMarginalLogLikelihood,
        'covar':MaternKernel(2.5) # Matern by default
    },
    'matern1_5':{
        'gp':SingleTaskGP,
        'likelihood':ExactMarginalLogLikelihood,
        'covar':MaternKernel(nu=1.5) # Matern by default
    },
    'matern0_5':{
        'gp':SingleTaskGP,
        'likelihood':ExactMarginalLogLikelihood,
        'covar':MaternKernel(nu=0.5) # Matern by default
    }
}

def initialize_first_batch(bounds, m=3):
    """
    bounds: the range in which we want to generate points.
    m: the power of 2 representing the number of Sobol points to generate.
    """
    d = bounds.shape[1]
    sobol_points = torch.tensor(Sobol(d=d, scramble=False).random_base2(m=m))
    # map each dimension to the bounds
    j = 0
    for i in bounds.T:
        sobol_points.T[j] = (i[1] - i[0]) * sobol_points.T[j] + i[0]
        j += 1
    return sobol_points

def prep_model(models, model_key, X_train, y_train, state_dict=None):
    """
    Initialize model according to specifications from the model dict and training data
    Hotload the params from state_dict to speed up likelihood fitting
    """
    model = models[model_key]['gp'](X_train, y_train, covar_module=models[model_key]['covar'])
    if state_dict is not None:
        model.load_state_dict(state_dict)
        
    mll = models[model_key]['likelihood'](model.likelihood, model)
    return mll, model

def training_loop(test_functions, function_key, 
                  models, model_key, acq_function,
                  loops, initialization_count_m=2, q=4):
    """
    Trains specified model on function defined by specified key for specified loop count
    """
    # initialize data
    rv = test_functions[function_key]['function']
    X_train = initialize_first_batch(test_functions[function_key]['bounds'], m=initialization_count_m)
    y_train = rv(X_train)
    if len(y_train.shape) == 1:
        y_train = y_train.unsqueeze(-1)
    mll, model = prep_model(models=models, model_key=model_key, X_train=X_train, y_train=y_train)
    
    # fit generate update loop
    for i in range(loops):
        # reload model
        mll, model = prep_model(models=models, 
            model_key=model_key, 
            X_train=X_train, 
            y_train=y_train,
            state_dict=model.state_dict())
        # fit model and acquisition function
        fit_gpytorch_mll(mll)
        best_value = y_train.max()
        
        if acq_function == qExpectedImprovement:
            acq = acq_function(model=model, best_f=best_value, maximize=True)
        if acq_function == qProbabilityOfImprovement:
            acq = acq_function(model=model, best_f=best_value)
        if acq_function == qUpperConfidenceBound:
            acq = acq_function(model=model, beta=0.2)
            
        # generate new points
        candidates, _ = optimize_acqf(
            acq_function=acq,
            bounds=test_functions[function_key]['bounds'],
            q=q,
            num_restarts=10,
            raw_samples=20,  # used for initialization heuristic
        )
        new_y = rv(candidates)
        if len(new_y.shape) == 1:
            new_y = new_y.unsqueeze(-1)
        X_train = torch.cat([X_train, candidates])
        y_train = torch.cat([y_train, new_y])
        best_value = y_train.max()
        
    return mll, model, X_train, y_train, best_value

# %%
performance = []

for model_key in models.keys():
    for function_key in test_functions.keys():
        for q in [1, 4, 16]:  
            for acq_function in [qExpectedImprovement, qProbabilityOfImprovement, qUpperConfidenceBound]:
                if acq_function == qExpectedImprovement:
                    acq_function_name = 'Expected Improvement'
                if acq_function == qProbabilityOfImprovement:
                    acq_function_name = 'Probability of Improvement'
                if acq_function == qUpperConfidenceBound:
                    acq_function_name = 'Upper Confidence Bound'
                
                print('attempting - function {} model {} q {} acq {}'\
                    .format(function_key, model_key, q, acq_function))
                loops = 256 // q
                mll, model, X_train, y_train, best_value = training_loop(test_functions, function_key=function_key,
                      models=models, model_key=model_key, acq_function=acq_function,
                      loops=loops, q=q)
                
                performance.append({
                    'Model':model_key,
                    'Test Function':function_key,
                    'Q':q,
                    'Acquisition Function':acq_function_name,
                    'Performance':float(best_value)
                })
                print(best_value)
                print('')
# Out:
# attempting - function sinc_plus_2 model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(0.9790)
#
# attempting - function sinc_plus_2 model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(0.0190)
#
# attempting - function sinc_plus_2 model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(0.0155)
#
# attempting - function sinc_plus_2 model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(0.9881)
#
# attempting - function sinc_plus_2 model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# tensor(0.9631)
#
# attempting - function sinc_plus_2 model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:328: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   warnings.warn(
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:328: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   warnings.warn(
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:328: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   warnings.warn(
# tensor(0.8608)
#
# attempting - function sinc_plus_2 model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(0.9036)
#
# attempting - function sinc_plus_2 model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(0.9863)
#
# attempting - function sinc_plus_2 model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(0.9267)
#
# attempting - function hartmann model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(2.3100)
#
# attempting - function hartmann model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(2.1458)
#
# attempting - function hartmann model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(2.9255)
#
# attempting - function hartmann model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(1.7486)
#
# attempting - function hartmann model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(2.1469)
#
# attempting - function hartmann model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(0.7465)
#
# attempting - function hartmann model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(2.0794)
#
# attempting - function hartmann model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(2.3634)
#
# attempting - function hartmann model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(2.2152)
#
# attempting - function ackley model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-4.1806)
#
# attempting - function ackley model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-7.5340)
#
# attempting - function ackley model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-7.5340)
#
# attempting - function ackley model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-7.5340)
#
# attempting - function ackley model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-6.1902)
#
# attempting - function ackley model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-2.7974)
#
# attempting - function ackley model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-7.5340)
#
# attempting - function ackley model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-1.0874)
#
# attempting - function ackley model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:328: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   warnings.warn(
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# tensor(-5.8034)
#
# attempting - function eggholder model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(882.1420)
#
# attempting - function eggholder model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(851.7379)
#
# attempting - function eggholder model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(915.1437)
#
# attempting - function eggholder model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(864.5737)
#
# attempting - function eggholder model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(636.2687)
#
# attempting - function eggholder model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(879.3832)
#
# attempting - function eggholder model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(800.1273)
#
# attempting - function eggholder model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(813.8553)
#
# attempting - function eggholder model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(888.5541)
#
# attempting - function cosine model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-0.2686)
#
# attempting - function cosine model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(0.0424)
#
# attempting - function cosine model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-0.3999)
#
# attempting - function cosine model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-0.4745)
#
# attempting - function cosine model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-0.1428)
#
# attempting - function cosine model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-0.4142)
#
# attempting - function cosine model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-0.3645)
#
# attempting - function cosine model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-0.6503)
#
# attempting - function cosine model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:328: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   warnings.warn(
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:328: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   warnings.warn(
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:328: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   warnings.warn(
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# tensor(-0.3536)
#
# attempting - function dixonprice model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-1.)
#
# attempting - function dixonprice model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-1.)
#
# attempting - function dixonprice model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-1.)
#
# attempting - function griewank model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-6.0016)
#
# attempting - function griewank model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-6.0016)
#
# attempting - function griewank model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-6.0016)
#
# attempting - function levy model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(573.9297)
#
# attempting - function levy model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(573.9297)
#
# attempting - function levy model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(573.9297)
#
# attempting - function powell model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-30.3125)
#
# attempting - function powell model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-30.3125)
#
# attempting - function powell model matern2_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-30.3125)
#
# attempting - function powell model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-30.3125)
#
# attempting - function powell model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-30.3125)
#
# attempting - function powell model matern2_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-30.3125)
#
# attempting - function powell model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-20.3744)
#
# attempting - function powell model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-30.3125)
#
# attempting - function powell model matern2_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-30.3125)
#
# attempting - function sinc_plus_2 model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(0.9965)
#
# attempting - function sinc_plus_2 model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(0.0441)
#
# attempting - function sinc_plus_2 model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(0.0193)
#
# attempting - function sinc_plus_2 model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(0.9979)
#
# attempting - function sinc_plus_2 model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(0.9997)
#
# attempting - function sinc_plus_2 model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(0.9640)
#
# attempting - function sinc_plus_2 model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(0.9894)
#
# attempting - function sinc_plus_2 model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:328: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   warnings.warn(
# tensor(0.9987)
#
# attempting - function sinc_plus_2 model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:328: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   warnings.warn(
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:328: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   warnings.warn(
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# tensor(1.0000)
#
# attempting - function hartmann model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(1.8250)
#
# attempting - function hartmann model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(2.6788)
#
# attempting - function hartmann model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(3.0406)
#
# attempting - function hartmann model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(2.0050)
#
# attempting - function hartmann model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(2.3655)
#
# attempting - function hartmann model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(1.1723)
#
# attempting - function hartmann model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(2.5795)
#
# attempting - function hartmann model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(1.6906)
#
# attempting - function hartmann model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(2.4616)
#
# attempting - function ackley model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-2.6154)
#
# attempting - function ackley model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-6.6260)
#
# attempting - function ackley model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-7.5340)
#
# attempting - function ackley model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-7.5340)
#
# attempting - function ackley model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-6.3106)
#
# attempting - function ackley model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-7.5340)
#
# attempting - function ackley model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-4.5246)
#
# attempting - function ackley model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-5.4941)
#
# attempting - function ackley model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-6.0876)
#
# attempting - function eggholder model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(879.2311)
#
# attempting - function eggholder model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(820.4871)
#
# attempting - function eggholder model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(934.7730)
#
# attempting - function eggholder model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(803.7992)
#
# attempting - function eggholder model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(748.1735)
#
# attempting - function eggholder model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(920.1961)
#
# attempting - function eggholder model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(785.2937)
#
# attempting - function eggholder model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(886.9519)
#
# attempting - function eggholder model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(868.7532)
#
# attempting - function cosine model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-0.1303)
#
# attempting - function cosine model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-0.0384)
#
# attempting - function cosine model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-0.3860)
#
# attempting - function cosine model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-0.4173)
#
# attempting - function cosine model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-0.2116)
#
# attempting - function cosine model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-0.7449)
#
# attempting - function cosine model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-0.2475)
#
# attempting - function cosine model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-0.3407)
#
# attempting - function cosine model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-0.5777)
#
# attempting - function dixonprice model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-1.)
#
# attempting - function dixonprice model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-1.)
#
# attempting - function dixonprice model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-1.)
#
# attempting - function griewank model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-6.0016)
#
# attempting - function griewank model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-6.0016)
#
# attempting - function griewank model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-6.0016)
#
# attempting - function levy model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(573.9297)
#
# attempting - function levy model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(573.9297)
#
# attempting - function levy model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(573.9297)
#
# attempting - function powell model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-30.3125)
#
# attempting - function powell model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-13.0001)
#
# attempting - function powell model matern1_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-30.3125)
#
# attempting - function powell model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-30.3125)
#
# attempting - function powell model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-30.3125)
#
# attempting - function powell model matern1_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-30.3125)
#
# attempting - function powell model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-11.6459)
#
# attempting - function powell model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-13.6742)
#
# attempting - function powell model matern1_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-17.4041)
#
# attempting - function sinc_plus_2 model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(0.9995)
#
# attempting - function sinc_plus_2 model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-3.8982e-17)
#
# attempting - function sinc_plus_2 model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(0.3427)
#
# attempting - function sinc_plus_2 model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(0.9980)
#
# attempting - function sinc_plus_2 model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(0.9878)
#
# attempting - function sinc_plus_2 model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(0.9840)
#
# attempting - function sinc_plus_2 model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(0.9935)
#
# attempting - function sinc_plus_2 model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(0.9703)
#
# attempting - function sinc_plus_2 model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(1.0000)
#
# attempting - function hartmann model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(2.2412)
#
# attempting - function hartmann model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(2.2571)
#
# attempting - function hartmann model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(3.0730)
#
# attempting - function hartmann model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(2.0926)
#
# attempting - function hartmann model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(2.7811)
#
# attempting - function hartmann model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# tensor(0.7465)
#
# attempting - function hartmann model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(2.4424)
#
# attempting - function hartmann model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(2.5521)
#
# attempting - function hartmann model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# /Users/eriqqc/workspace/gaussian_process_benchmarks/botorch/botorch/optim/optimize.py:306: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#   warnings.warn(first_warn_msg, RuntimeWarning)
# tensor(0.7465)
#
# attempting - function ackley model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-4.8125)
#
# attempting - function ackley model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-5.2478)
#
# attempting - function ackley model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-2.1502)
#
# attempting - function ackley model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-5.4240)
#
# attempting - function ackley model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-7.5340)
#
# attempting - function ackley model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-6.2881)
#
# attempting - function ackley model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-7.5340)
#
# attempting - function ackley model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-4.4799)
#
# attempting - function ackley model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-5.6519)
#
# attempting - function eggholder model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(807.5282)
#
# attempting - function eggholder model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(911.7843)
#
# attempting - function eggholder model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(732.5816)
#
# attempting - function eggholder model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(888.6506)
#
# attempting - function eggholder model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(744.7565)
#
# attempting - function eggholder model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(936.6960)
#
# attempting - function eggholder model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(888.6952)
#
# attempting - function eggholder model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(802.5060)
#
# attempting - function eggholder model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(839.0511)
#
# attempting - function cosine model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-0.4266)
#
# attempting - function cosine model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-0.4647)
#
# attempting - function cosine model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-0.2035)
#
# attempting - function cosine model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-0.2673)
#
# attempting - function cosine model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-0.3238)
#
# attempting - function cosine model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-0.7457)
#
# attempting - function cosine model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-0.4149)
#
# attempting - function cosine model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-0.3918)
#
# attempting - function cosine model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-0.7457)
#
# attempting - function dixonprice model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-1.)
#
# attempting - function dixonprice model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-1.)
#
# attempting - function dixonprice model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-1.)
#
# attempting - function dixonprice model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-1.)
#
# attempting - function griewank model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-6.0016)
#
# attempting - function griewank model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-6.0016)
#
# attempting - function griewank model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-6.0016)
#
# attempting - function griewank model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-6.0016)
#
# attempting - function levy model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(573.9297)
#
# attempting - function levy model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(573.9297)
#
# attempting - function levy model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(573.9297)
#
# attempting - function levy model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(573.9297)
#
# attempting - function powell model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-14.5370)
#
# attempting - function powell model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-30.3125)
#
# attempting - function powell model matern0_5 q 1 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-20.6747)
#
# attempting - function powell model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-30.3125)
#
# attempting - function powell model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-19.5309)
#
# attempting - function powell model matern0_5 q 4 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-30.3125)
#
# attempting - function powell model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qExpectedImprovement'>
# tensor(-30.3125)
#
# attempting - function powell model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qProbabilityOfImprovement'>
# tensor(-30.3125)
#
# attempting - function powell model matern0_5 q 16 acq <class 'botorch.acquisition.monte_carlo.qUpperConfidenceBound'>
# tensor(-30.3125)

# %%
print(performance)
# Out:
# [{'Model': 'matern2_5', 'Test Function': 'sinc_plus_2', 'Q': 1, 'Acquisition Function': 'Expected Improvement', 'Performance': 0.9790379869855272}, {'Model': 'matern2_5', 'Test Function': 'sinc_plus_2', 'Q': 1, 'Acquisition Function': 'Probability of Improvement', 'Performance': 0.01897608328852435}, {'Model': 'matern2_5', 'Test Function': 'sinc_plus_2', 'Q': 1, 'Acquisition Function': 'Upper Confidence Bound', 'Performance': 0.01552081689641406}, {'Model': 'matern2_5', 'Test Function': 'sinc_plus_2', 'Q': 4, 'Acquisition Function': 'Expected Improvement', 'Performance': 0.9880810856966564}, {'Model': 'matern2_5', 'Test Function': 'sinc_plus_2', 'Q': 4, 'Acquisition Function': 'Probability of Improvement', 'Performance': 0.9630629127866782}, {'Model': 'matern2_5', 'Test Function': 'sinc_plus_2', 'Q': 4, 'Acquisition Function': 'Upper Confidence Bound', 'Performance': 0.8608320234819088}, {'Model': 'matern2_5', 'Test Function': 'sinc_plus_2', 'Q': 16, 'Acquisition Function': 'Expected Improvement', 'Performance': 0.9035597637669054}, {'Model': 'matern2_5', 'Test Function': 'sinc_plus_2', 'Q': 16, 'Acquisition Function': 'Probability of Improvement', 'Performance': 0.98633798150708}, {'Model': 'matern2_5', 'Test Function': 'sinc_plus_2', 'Q': 16, 'Acquisition Function': 'Upper Confidence Bound', 'Performance': 0.9267291805765749}, {'Model': 'matern2_5', 'Test Function': 'hartmann', 'Q': 1, 'Acquisition Function': 'Expected Improvement', 'Performance': 2.3100469087217586}, {'Model': 'matern2_5', 'Test Function': 'hartmann', 'Q': 1, 'Acquisition Function': 'Probability of Improvement', 'Performance': 2.1458305327396046}, {'Model': 'matern2_5', 'Test Function': 'hartmann', 'Q': 1, 'Acquisition Function': 'Upper Confidence Bound', 'Performance': 2.925540628522455}, {'Model': 'matern2_5', 'Test Function': 'hartmann', 'Q': 4, 'Acquisition Function': 'Expected Improvement', 'Performance': 1.7485512925094953}, {'Model': 'matern2_5', 'Test Function': 'hartmann', 'Q': 4, 'Acquisition Function': 'Probability of Improvement', 'Performance': 2.146921917239905}, {'Model': 'matern2_5', 'Test Function': 'hartmann', 'Q': 4, 'Acquisition Function': 'Upper Confidence Bound', 'Performance': 0.7464926878436263}, {'Model': 'matern2_5', 'Test Function': 'hartmann', 'Q': 16, 'Acquisition Function': 'Expected Improvement', 'Performance': 2.079446682504432}, {'Model': 'matern2_5', 'Test Function': 'hartmann', 'Q': 16, 'Acquisition Function': 'Probability of Improvement', 'Performance': 2.363369764703308}, {'Model': 'matern2_5', 'Test Function': 'hartmann', 'Q': 16, 'Acquisition Function': 'Upper Confidence Bound', 'Performance': 2.2151729214972637}, {'Model': 'matern2_5', 'Test Function': 'ackley', 'Q': 1, 'Acquisition Function': 'Expected Improvement', 'Performance': -4.180609828652901}, {'Model': 'matern2_5', 'Test Function': 'ackley', 'Q': 1, 'Acquisition Function': 'Probability of Improvement', 'Performance': -7.534037973653245}, {'Model': 'matern2_5', 'Test Function': 'ackley', 'Q': 1, 'Acquisition Function': 'Upper Confidence Bound', 'Performance': -7.534037973653245}, {'Model': 'matern2_5', 'Test Function': 'ackley', 'Q': 4, 'Acquisition Function': 'Expected Improvement', 'Performance': -7.534037973653245}, {'Model': 'matern2_5', 'Test Function': 'ackley', 'Q': 4, 'Acquisition Function': 'Probability of Improvement', 'Performance': -6.190176570191291}, {'Model': 'matern2_5', 'Test Function': 'ackley', 'Q': 4, 'Acquisition Function': 'Upper Confidence Bound', 'Performance': -2.79744836367728}, {'Model': 'matern2_5', 'Test Function': 'ackley', 'Q': 16, 'Acquisition Function': 'Expected Improvement', 'Performance': -7.534037973653245}, {'Model': 'matern2_5', 'Test Function': 'ackley', 'Q': 16, 'Acquisition Function': 'Probability of Improvement', 'Performance': -1.0874034242419381}, {'Model': 'matern2_5', 'Test Function': 'ackley', 'Q': 16, 'Acquisition Function': 'Upper Confidence Bound', 'Performance': -5.8033601896448594}, {'Model': 'matern2_5', ' ...

# %%
with pd.option_context('display.max_rows', None):
    display(pd.DataFrame(performance))
# Out:
#          Model Test Function   Q        Acquisition Function   Performance
# 0    matern2_5   sinc_plus_2   1        Expected Improvement  9.790380e-01
# 1    matern2_5   sinc_plus_2   1  Probability of Improvement  1.897608e-02
# 2    matern2_5   sinc_plus_2   1      Upper Confidence Bound  1.552082e-02
# 3    matern2_5   sinc_plus_2   4        Expected Improvement  9.880811e-01
# 4    matern2_5   sinc_plus_2   4  Probability of Improvement  9.630629e-01
# 5    matern2_5   sinc_plus_2   4      Upper Confidence Bound  8.608320e-01
# 6    matern2_5   sinc_plus_2  16        Expected Improvement  9.035598e-01
# 7    matern2_5   sinc_plus_2  16  Probability of Improvement  9.863380e-01
# 8    matern2_5   sinc_plus_2  16      Upper Confidence Bound  9.267292e-01
# 9    matern2_5      hartmann   1        Expected Improvement  2.310047e+00
# 10   matern2_5      hartmann   1  Probability of Improvement  2.145831e+00
# 11   matern2_5      hartmann   1      Upper Confidence Bound  2.925541e+00
# 12   matern2_5      hartmann   4        Expected Improvement  1.748551e+00
# 13   matern2_5      hartmann   4  Probability of Improvement  2.146922e+00
# 14   matern2_5      hartmann   4      Upper Confidence Bound  7.464927e-01
# 15   matern2_5      hartmann  16        Expected Improvement  2.079447e+00
# 16   matern2_5      hartmann  16  Probability of Improvement  2.363370e+00
# 17   matern2_5      hartmann  16      Upper Confidence Bound  2.215173e+00
# 18   matern2_5        ackley   1        Expected Improvement -4.180610e+00
# 19   matern2_5        ackley   1  Probability of Improvement -7.534038e+00
# 20   matern2_5        ackley   1      Upper Confidence Bound -7.534038e+00
# 21   matern2_5        ackley   4        Expected Improvement -7.534038e+00
# 22   matern2_5        ackley   4  Probability of Improvement -6.190177e+00
# 23   matern2_5        ackley   4      Upper Confidence Bound -2.797448e+00
# 24   matern2_5        ackley  16        Expected Improvement -7.534038e+00
# 25   matern2_5        ackley  16  Probability of Improvement -1.087403e+00
# 26   matern2_5        ackley  16      Upper Confidence Bound -5.803360e+00
# 27   matern2_5     eggholder   1        Expected Improvement  8.821420e+02
# 28   matern2_5     eggholder   1  Probability of Improvement  8.517379e+02
# 29   matern2_5     eggholder   1      Upper Confidence Bound  9.151437e+02
# 30   matern2_5     eggholder   4        Expected Improvement  8.645737e+02
# 31   matern2_5     eggholder   4  Probability of Improvement  6.362687e+02
# 32   matern2_5     eggholder   4      Upper Confidence Bound  8.793832e+02
# 33   matern2_5     eggholder  16        Expected Improvement  8.001273e+02
# 34   matern2_5     eggholder  16  Probability of Improvement  8.138553e+02
# 35   matern2_5     eggholder  16      Upper Confidence Bound  8.885541e+02
# 36   matern2_5        cosine   1        Expected Improvement -2.685845e-01
# 37   matern2_5        cosine   1  Probability of Improvement  4.241042e-02
# 38   matern2_5        cosine   1      Upper Confidence Bound -3.999362e-01
# 39   matern2_5        cosine   4        Expected Improvement -4.744612e-01
# 40   matern2_5        cosine   4  Probability of Improvement -1.428326e-01
# 41   matern2_5        cosine   4      Upper Confidence Bound -4.142369e-01
# 42   matern2_5        cosine  16        Expected Improvement -3.645500e-01
# 43   matern2_5        cosine  16  Probability of Improvement -6.503477e-01
# 44   matern2_5        cosine  16      Upper Confidence Bound -3.535814e-01
# 45   matern2_5    dixonprice   1        Expected Improvement -1.000000e+00
# 46   matern2_5    dixonprice   1  Probability of Improvement -1.000000e+00
# 47   matern2_5    dixonprice   1      Upper Confidence Bound -1.000000e+00
# 48   matern2_5    dixonprice   4        Expected Improvement -1.000000e+00
# 49   matern2_5    dixonprice   4  Probability of Improvement -1.000000e+00
# 50   matern2_5    dixonprice   4      Upper Confidence Bound -1.000000e+00
# 51   matern2_5    dixonprice  16        Expected Improvement -1.000000e+00
# 52   matern2_5    dixonprice  16  Probability of Improvement -1.000000e+00
# 53   matern2_5    dixonprice  16      Upper Confidence Bound -1.000000e+00
# 54   matern2_5      griewank   1        Expected Improvement -6.001590e+00
# 55   matern2_5      griewank   1  Probability of Improvement -6.001590e+00
# 56   matern2_5      griewank   1      Upper Confidence Bound -6.001590e+00
# 57   matern2_5      griewank   4        Expected Improvement -6.001590e+00
# 58   matern2_5      griewank   4  Probability of Improvement -6.001590e+00
# 59   matern2_5      griewank   4      Upper Confidence Bound -6.001590e+00
# 60   matern2_5      griewank  16        Expected Improvement -6.001590e+00
# 61   matern2_5      griewank  16  Probability of Improvement -6.001590e+00
# 62   matern2_5      griewank  16      Upper Confidence Bound -6.001590e+00
# 63   matern2_5          levy   1        Expected Improvement  5.739297e+02
# 64   matern2_5          levy   1  Probability of Improvement  5.739297e+02
# 65   matern2_5          levy   1      Upper Confidence Bound  5.739297e+02
# 66   matern2_5          levy   4        Expected Improvement  5.739297e+02
# 67   matern2_5          levy   4  Probability of Improvement  5.739297e+02
# 68   matern2_5          levy   4      Upper Confidence Bound  5.739297e+02
# 69   matern2_5          levy  16        Expected Improvement  5.739297e+02
# 70   matern2_5          levy  16  Probability of Improvement  5.739297e+02
# 71   matern2_5          levy  16      Upper Confidence Bound  5.739297e+02
# 72   matern2_5        powell   1        Expected Improvement -3.031250e+01
# 73   matern2_5        powell   1  Probability of Improvement -3.031250e+01
# 74   matern2_5        powell   1      Upper Confidence Bound -3.031250e+01
# 75   matern2_5        powell   4        Expected Improvement -3.031250e+01
# 76   matern2_5        powell   4  Probability of Improvement -3.031250e+01
# 77   matern2_5        powell   4      Upper Confidence Bound -3.031250e+01
# 78   matern2_5        powell  16        Expected Improvement -2.037442e+01
# 79   matern2_5        powell  16  Probability of Improvement -3.031250e+01
# 80   matern2_5        powell  16      Upper Confidence Bound -3.031250e+01
# 81   matern1_5   sinc_plus_2   1        Expected Improvement  9.965497e-01
# 82   matern1_5   sinc_plus_2   1  Probability of Improvement  4.408601e-02
# 83   matern1_5   sinc_plus_2   1      Upper Confidence Bound  1.928679e-02
# 84   matern1_5   sinc_plus_2   4        Expected Improvement  9.978566e-01
# 85   matern1_5   sinc_plus_2   4  Probability of Improvement  9.997405e-01
# 86   matern1_5   sinc_plus_2   4      Upper Confidence Bound  9.639837e-01
# 87   matern1_5   sinc_plus_2  16        Expected Improvement  9.894088e-01
# 88   matern1_5   sinc_plus_2  16  Probability of Improvement  9.987387e-01
# 89   matern1_5   sinc_plus_2  16      Upper Confidence Bound  9.999926e-01
# 90   matern1_5      hartmann   1        Expected Improvement  1.825018e+00
# 91   matern1_5      hartmann   1  Probability of Improvement  2.678764e+00
# 92   matern1_5      hartmann   1      Upper Confidence Bound  3.040563e+00
# 93   matern1_5      hartmann   4        Expected Improvement  2.004992e+00
# 94   matern1_5      hartmann   4  Probability of Improvement  2.365491e+00
# 95   matern1_5      hartmann   4      Upper Confidence Bound  1.172294e+00
# 96   matern1_5      hartmann  16        Expected Improvement  2.579540e+00
# 97   matern1_5      hartmann  16  Probability of Improvement  1.690636e+00
# 98   matern1_5      hartmann  16      Upper Confidence Bound  2.461558e+00
# 99   matern1_5        ackley   1        Expected Improvement -2.615430e+00
# 100  matern1_5        ackley   1  Probability of Improvement -6.625989e+00
# 101  matern1_5        ackley   1      Upper Confidence Bound -7.534038e+00
# 102  matern1_5        ackley   4        Expected Improvement -7.534038e+00
# 103  matern1_5        ackley   4  Probability of Improvement -6.310580e+00
# 104  matern1_5        ackley   4      Upper Confidence Bound -7.534038e+00
# 105  matern1_5        ackley  16        Expected Improvement -4.524579e+00
# 106  matern1_5        ackley  16  Probability of Improvement -5.494064e+00
# 107  matern1_5        ackley  16      Upper Confidence Bound -6.087604e+00
# 108  matern1_5     eggholder   1        Expected Improvement  8.792311e+02
# 109  matern1_5     eggholder   1  Probability of Improvement  8.204871e+02
# 110  matern1_5     eggholder   1      Upper Confidence Bound  9.347730e+02
# 111  matern1_5     eggholder   4        Expected Improvement  8.037992e+02
# 112  matern1_5     eggholder   4  Probability of Improvement  7.481735e+02
# 113  matern1_5     eggholder   4      Upper Confidence Bound  9.201961e+02
# 114  matern1_5     eggholder  16        Expected Improvement  7.852937e+02
# 115  matern1_5     eggholder  16  Probability of Improvement  8.869519e+02
# 116  matern1_5     eggholder  16      Upper Confidence Bound  8.687532e+02
# 117  matern1_5        cosine   1        Expected Improvement -1.302874e-01
# 118  matern1_5        cosine   1  Probability of Improvement -3.839836e-02
# 119  matern1_5        cosine   1      Upper Confidence Bound -3.859633e-01
# 120  matern1_5        cosine   4        Expected Improvement -4.173062e-01
# 121  matern1_5        cosine   4  Probability of Improvement -2.116451e-01
# 122  matern1_5        cosine   4      Upper Confidence Bound -7.449375e-01
# 123  matern1_5        cosine  16        Expected Improvement -2.474648e-01
# 124  matern1_5        cosine  16  Probability of Improvement -3.407075e-01
# 125  matern1_5        cosine  16      Upper Confidence Bound -5.776645e-01
# 126  matern1_5    dixonprice   1        Expected Improvement -1.000000e+00
# 127  matern1_5    dixonprice   1  Probability of Improvement -1.000000e+00
# 128  matern1_5    dixonprice   1      Upper Confidence Bound -1.000000e+00
# 129  matern1_5    dixonprice   4        Expected Improvement -1.000000e+00
# 130  matern1_5    dixonprice   4  Probability of Improvement -1.000000e+00
# 131  matern1_5    dixonprice   4      Upper Confidence Bound -1.000000e+00
# 132  matern1_5    dixonprice  16        Expected Improvement -1.000000e+00
# 133  matern1_5    dixonprice  16  Probability of Improvement -1.000000e+00
# 134  matern1_5    dixonprice  16      Upper Confidence Bound -1.000000e+00
# 135  matern1_5      griewank   1        Expected Improvement -6.001590e+00
# 136  matern1_5      griewank   1  Probability of Improvement -6.001590e+00
# 137  matern1_5      griewank   1      Upper Confidence Bound -6.001590e+00
# 138  matern1_5      griewank   4        Expected Improvement -6.001590e+00
# 139  matern1_5      griewank   4  Probability of Improvement -6.001590e+00
# 140  matern1_5      griewank   4      Upper Confidence Bound -6.001590e+00
# 141  matern1_5      griewank  16        Expected Improvement -6.001590e+00
# 142  matern1_5      griewank  16  Probability of Improvement -6.001590e+00
# 143  matern1_5      griewank  16      Upper Confidence Bound -6.001590e+00
# 144  matern1_5          levy   1        Expected Improvement  5.739297e+02
# 145  matern1_5          levy   1  Probability of Improvement  5.739297e+02
# 146  matern1_5          levy   1      Upper Confidence Bound  5.739297e+02
# 147  matern1_5          levy   4        Expected Improvement  5.739297e+02
# 148  matern1_5          levy   4  Probability of Improvement  5.739297e+02
# 149  matern1_5          levy   4      Upper Confidence Bound  5.739297e+02
# 150  matern1_5          levy  16        Expected Improvement  5.739297e+02
# 151  matern1_5          levy  16  Probability of Improvement  5.739297e+02
# 152  matern1_5          levy  16      Upper Confidence Bound  5.739297e+02
# 153  matern1_5        powell   1        Expected Improvement -3.031250e+01
# 154  matern1_5        powell   1  Probability of Improvement -1.300011e+01
# 155  matern1_5        powell   1      Upper Confidence Bound -3.031250e+01
# 156  matern1_5        powell   4        Expected Improvement -3.031250e+01
# 157  matern1_5        powell   4  Probability of Improvement -3.031250e+01
# 158  matern1_5        powell   4      Upper Confidence Bound -3.031250e+01
# 159  matern1_5        powell  16        Expected Improvement -1.164588e+01
# 160  matern1_5        powell  16  Probability of Improvement -1.367419e+01
# 161  matern1_5        powell  16      Upper Confidence Bound -1.740406e+01
# 162  matern0_5   sinc_plus_2   1        Expected Improvement  9.995297e-01
# 163  matern0_5   sinc_plus_2   1  Probability of Improvement -3.898172e-17
# 164  matern0_5   sinc_plus_2   1      Upper Confidence Bound  3.427421e-01
# 165  matern0_5   sinc_plus_2   4        Expected Improvement  9.980447e-01
# 166  matern0_5   sinc_plus_2   4  Probability of Improvement  9.877558e-01
# 167  matern0_5   sinc_plus_2   4      Upper Confidence Bound  9.839728e-01
# 168  matern0_5   sinc_plus_2  16        Expected Improvement  9.934859e-01
# 169  matern0_5   sinc_plus_2  16  Probability of Improvement  9.703002e-01
# 170  matern0_5   sinc_plus_2  16      Upper Confidence Bound  9.999642e-01
# 171  matern0_5      hartmann   1        Expected Improvement  2.241206e+00
# 172  matern0_5      hartmann   1  Probability of Improvement  2.257121e+00
# 173  matern0_5      hartmann   1      Upper Confidence Bound  3.073004e+00
# 174  matern0_5      hartmann   4        Expected Improvement  2.092582e+00
# 175  matern0_5      hartmann   4  Probability of Improvement  2.781128e+00
# 176  matern0_5      hartmann   4      Upper Confidence Bound  7.464927e-01
# 177  matern0_5      hartmann  16        Expected Improvement  2.442387e+00
# 178  matern0_5      hartmann  16  Probability of Improvement  2.552089e+00
# 179  matern0_5      hartmann  16      Upper Confidence Bound  7.464927e-01
# 180  matern0_5        ackley   1        Expected Improvement -4.812498e+00
# 181  matern0_5        ackley   1  Probability of Improvement -5.247782e+00
# 182  matern0_5        ackley   1      Upper Confidence Bound -2.150220e+00
# 183  matern0_5        ackley   4        Expected Improvement -5.424006e+00
# 184  matern0_5        ackley   4  Probability of Improvement -7.534038e+00
# 185  matern0_5        ackley   4      Upper Confidence Bound -6.288126e+00
# 186  matern0_5        ackley  16        Expected Improvement -7.534038e+00
# 187  matern0_5        ackley  16  Probability of Improvement -4.479885e+00
# 188  matern0_5        ackley  16      Upper Confidence Bound -5.651867e+00
# 189  matern0_5     eggholder   1        Expected Improvement  8.075282e+02
# 190  matern0_5     eggholder   1  Probability of Improvement  9.117843e+02
# 191  matern0_5     eggholder   1      Upper Confidence Bound  7.325816e+02
# 192  matern0_5     eggholder   4        Expected Improvement  8.886506e+02
# 193  matern0_5     eggholder   4  Probability of Improvement  7.447565e+02
# 194  matern0_5     eggholder   4      Upper Confidence Bound  9.366960e+02
# 195  matern0_5     eggholder  16        Expected Improvement  8.886952e+02
# 196  matern0_5     eggholder  16  Probability of Improvement  8.025060e+02
# 197  matern0_5     eggholder  16      Upper Confidence Bound  8.390511e+02
# 198  matern0_5        cosine   1        Expected Improvement -4.265964e-01
# 199  matern0_5        cosine   1  Probability of Improvement -4.646580e-01
# 200  matern0_5        cosine   1      Upper Confidence Bound -2.035342e-01
# 201  matern0_5        cosine   4        Expected Improvement -2.672786e-01
# 202  matern0_5        cosine   4  Probability of Improvement -3.238442e-01
# 203  matern0_5        cosine   4      Upper Confidence Bound -7.456854e-01
# 204  matern0_5        cosine  16        Expected Improvement -4.148808e-01
# 205  matern0_5        cosine  16  Probability of Improvement -3.917814e-01
# 206  matern0_5        cosine  16      Upper Confidence Bound -7.456854e-01
# 207  matern0_5    dixonprice   1        Expected Improvement -1.000000e+00
# 208  matern0_5    dixonprice   1  Probability of Improvement -1.000000e+00
# 209  matern0_5    dixonprice   1      Upper Confidence Bound -1.000000e+00
# 210  matern0_5    dixonprice   4        Expected Improvement -1.000000e+00
# 211  matern0_5    dixonprice   4  Probability of Improvement -1.000000e+00
# 212  matern0_5    dixonprice   4      Upper Confidence Bound -1.000000e+00
# 213  matern0_5    dixonprice  16        Expected Improvement -1.000000e+00
# 214  matern0_5    dixonprice  16  Probability of Improvement -1.000000e+00
# 215  matern0_5    dixonprice  16      Upper Confidence Bound -1.000000e+00
# 216  matern0_5      griewank   1        Expected Improvement -6.001590e+00
# 217  matern0_5      griewank   1  Probability of Improvement -6.001590e+00
# 218  matern0_5      griewank   1      Upper Confidence Bound -6.001590e+00
# 219  matern0_5      griewank   4        Expected Improvement -6.001590e+00
# 220  matern0_5      griewank   4  Probability of Improvement -6.001590e+00
# 221  matern0_5      griewank   4      Upper Confidence Bound -6.001590e+00
# 222  matern0_5      griewank  16        Expected Improvement -6.001590e+00
# 223  matern0_5      griewank  16  Probability of Improvement -6.001590e+00
# 224  matern0_5      griewank  16      Upper Confidence Bound -6.001590e+00
# 225  matern0_5          levy   1        Expected Improvement  5.739297e+02
# 226  matern0_5          levy   1  Probability of Improvement  5.739297e+02
# 227  matern0_5          levy   1      Upper Confidence Bound  5.739297e+02
# 228  matern0_5          levy   4        Expected Improvement  5.739297e+02
# 229  matern0_5          levy   4  Probability of Improvement  5.739297e+02
# 230  matern0_5          levy   4      Upper Confidence Bound  5.739297e+02
# 231  matern0_5          levy  16        Expected Improvement  5.739297e+02
# 232  matern0_5          levy  16  Probability of Improvement  5.739297e+02
# 233  matern0_5          levy  16      Upper Confidence Bound  5.739297e+02
# 234  matern0_5        powell   1        Expected Improvement -1.453702e+01
# 235  matern0_5        powell   1  Probability of Improvement -3.031250e+01
# 236  matern0_5        powell   1      Upper Confidence Bound -2.067467e+01
# 237  matern0_5        powell   4        Expected Improvement -3.031250e+01
# 238  matern0_5        powell   4  Probability of Improvement -1.953091e+01
# 239  matern0_5        powell   4      Upper Confidence Bound -3.031250e+01
# 240  matern0_5        powell  16        Expected Improvement -3.031250e+01
# 241  matern0_5        powell  16  Probability of Improvement -3.031250e+01
# 242  matern0_5        powell  16      Upper Confidence Bound -3.031250e+01

# %%
pd.DataFrame(performance).to_csv('results.csv', index=False)

# %%
pd.DataFrame(performance).pivot(index=['Model', 'Q', 'Acquisition Function'], 
                                columns='Test Function', 
                                values='Performance')
# Out:
# Test Function                              ackley    cosine  dixonprice  \
# Model     Q  Acquisition Function
# matern0_5 1  Expected Improvement       -4.812498 -0.426596        -1.0
#              Probability of Improvement -5.247782 -0.464658        -1.0
#              Upper Confidence Bound     -2.150220 -0.203534        -1.0
#           4  Expected Improvement       -5.424006 -0.267279        -1.0
#              Probability of Improvement -7.534038 -0.323844        -1.0
#              Upper Confidence Bound     -6.288126 -0.745685        -1.0
#           16 Expected Improvement       -7.534038 -0.414881        -1.0
#              Probability of Improvement -4.479885 -0.391781        -1.0
#              Upper Confidence Bound     -5.651867 -0.745685        -1.0
# matern1_5 1  Expected Improvement       -2.615430 -0.130287        -1.0
#              Probability of Improvement -6.625989 -0.038398        -1.0
#              Upper Confidence Bound     -7.534038 -0.385963        -1.0
#           4  Expected Improvement       -7.534038 -0.417306        -1.0
#              Probability of Improvement -6.310580 -0.211645        -1.0
#              Upper Confidence Bound     -7.534038 -0.744938        -1.0
#           16 Expected Improvement       -4.524579 -0.247465        -1.0
#              Probability of Improvement -5.494064 -0.340707        -1.0
#              Upper Confidence Bound     -6.087604 -0.577665        -1.0
# matern2_5 1  Expected Improvement       -4.180610 -0.268585        -1.0
#              Probability of Improvement -7.534038  0.042410        -1.0
#              Upper Confidence Bound     -7.534038 -0.399936        -1.0
#           4  Expected Improvement       -7.534038 -0.474461        -1.0
#              Probability of Improvement -6.190177 -0.142833        -1.0
#              Upper Confidence Bound     -2.797448 -0.414237        -1.0
#           16 Expected Improvement       -7.534038 -0.364550        -1.0
#              Probability of Improvement -1.087403 -0.650348        -1.0
#              Upper Confidence Bound     -5.803360 -0.353581        -1.0
#
# Test Function                             eggholder  griewank  hartmann  \
# Model     Q  Acquisition Function
# matern0_5 1  Expected Improvement        807.528242  -6.00159  2.241206
#              Probability of Improvement  911.784328  -6.00159  2.257121
#              Upper Confidence Bound      732.581616  -6.00159  3.073004
#           4  Expected Improvement        888.650574  -6.00159  2.092582
#              Probability of Improvement  744.756499  -6.00159  2.781128
#              Upper Confidence Bound      936.695988  -6.00159  0.746493
#           16 Expected Improvement        888.695180  -6.00159  2.442387
#              Probability of Improvement  802.505953  -6.00159  2.552089
#              Upper Confidence Bound      839.051077  -6.00159  0.746493
# matern1_5 1  Expected Improvement        879.231101  -6.00159  1.825018
#              Probability of Improvement  820.487134  -6.00159  2.678764
#              Upper Confidence Bound      934.772976  -6.00159  3.040563
#           4  Expected Improvement        803.799186  -6.00159  2.004992
#              Probability of Improvement  748.173457  -6.00159  2.365491
#              Upper Confidence Bound      920.196100  -6.00159  1.172294
#           16 Expected Improvement        785.293729  -6.00159  2.579540
#              Probability of Improvement  886.951887  -6.00159  1.690636
#              Upper Confidence Bound      868.753200  -6.00159  2.461558
# matern2_5 1  Expected Improvement        882.142015  -6.00159  2.310047
#              Probability of Improvement  851.737919  -6.00159  2.145831
#              Upper Confidence Bound      915.143731  -6.00159  2.925541
#           4  Expected Improvement        864.573705  -6.00159  1.748551
#              Probability of Improvement  636.268710  -6.00159  2.146922
#              Upper Confidence Bound      879.383215  -6.00159  0.746493
#           16 Expected Improvement        800.127332  -6.00159  2.079447
#              Probability of Improvement  813.855345  -6.00159  2.363370
#              Upper Confidence Bound      888.554085  -6.00159  2.215173
#
# Test Function                                  levy     powell   sinc_plus_2
# Model     Q  Acquisition Function
# matern0_5 1  Expected Improvement        573.929663 -14.537016  9.995297e-01
#              Probability of Improvement  573.929663 -30.312500 -3.898172e-17
#              Upper Confidence Bound      573.929663 -20.674674  3.427421e-01
#           4  Expected Improvement        573.929663 -30.312500  9.980447e-01
#              Probability of Improvement  573.929663 -19.530906  9.877558e-01
#              Upper Confidence Bound      573.929663 -30.312500  9.839728e-01
#           16 Expected Improvement        573.929663 -30.312500  9.934859e-01
#              Probability of Improvement  573.929663 -30.312500  9.703002e-01
#              Upper Confidence Bound      573.929663 -30.312500  9.999642e-01
# matern1_5 1  Expected Improvement        573.929663 -30.312500  9.965497e-01
#              Probability of Improvement  573.929663 -13.000110  4.408601e-02
#              Upper Confidence Bound      573.929663 -30.312500  1.928679e-02
#           4  Expected Improvement        573.929663 -30.312500  9.978566e-01
#              Probability of Improvement  573.929663 -30.312500  9.997405e-01
#              Upper Confidence Bound      573.929663 -30.312500  9.639837e-01
#           16 Expected Improvement        573.929663 -11.645883  9.894088e-01
#              Probability of Improvement  573.929663 -13.674185  9.987387e-01
#              Upper Confidence Bound      573.929663 -17.404065  9.999926e-01
# matern2_5 1  Expected Improvement        573.929663 -30.312500  9.790380e-01
#              Probability of Improvement  573.929663 -30.312500  1.897608e-02
#              Upper Confidence Bound      573.929663 -30.312500  1.552082e-02
#           4  Expected Improvement        573.929663 -30.312500  9.880811e-01
#              Probability of Improvement  573.929663 -30.312500  9.630629e-01
#              Upper Confidence Bound      573.929663 -30.312500  8.608320e-01
#           16 Expected Improvement        573.929663 -20.374424  9.035598e-01
#              Probability of Improvement  573.929663 -30.312500  9.863380e-01
#              Upper Confidence Bound      573.929663 -30.312500  9.267292e-01
